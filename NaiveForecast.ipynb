# %% [markdown]
# ## Setup

# %%
import pandas as pd

# %%
# The dataframe is relatively large and we want to visualise it as a scrollable element
pd.set_option('display.max_columns', None)

# %%
# Importing the dataset
df = pd.read_csv('cleaned_data.csv')

# %%
# Check if succeeded
df.shape
# Out:
# (818375, 23)

# %%
# Only adjust the copy version
data = df.copy()

# %%
data.head()
# Out:
#    Unnamed: 0  DimPostingDateId  DimGenderId  DimItemId              ItemNo2  \
# 0           0          20220312            2     347900  F15404308_CLR000021
# 1           1          20220312            2     347900  F15404308_CLR000021
# 2           2          20220312            1        778  M00012003_CLR000508
# 3           3          20220312            2     348547  F19123672_CLR000021
# 4           4          20220312            2     348547  F19123672_CLR000021
#
#      StyleID                Style       Color Size      Gender  Category  \
# 0  F15404308      Hoys pants 6528       Black   XL  WOMENSWEAR  Trousers
# 1  F15404308      Hoys pants 6528       Black   XL  WOMENSWEAR  Trousers
# 2  M00012003    Kronos o-n ss 273  White mel     S    MENSWEAR      Tops
# 3  F19123672  Majan ss shirt 9942       Black    L  WOMENSWEAR    Shirts
# 4  F19123672  Majan ss shirt 9942       Black    L  WOMENSWEAR    Shirts
#
#   SUB Category SUB Category2 Quality Origin Country  WHSSalesPriceDKK  \
# 0     Trousers       Default   Woven          China             315.0
# 1     Trousers       Default   Woven          China             315.0
# 2    Crew neck  Short sleeve  Jersey         Turkey              90.0
# 3       Shirts  Short sleeve   Woven          China             195.0
# 4       Shirts  Short sleeve   Woven          China             195.0
#
#    RRSalesPriceDKK OrderHeaderNumber  OrderLineNumber  Quantity  Amount  \
# 0            800.0            103099            20001       1.0  294.63
# 1            800.0            103106            20002       2.0  589.26
# 2            250.0            103035            20002       1.0   78.12
# 3            500.0         IN0001122            60002       2.0  379.45
# 4            500.0            103113            40003       2.0  379.45
#
#    Discount    Cost
# 0     17.71  152.91
# 1     35.34  305.80
# 2      0.00   42.41
# 3      0.00  147.84
# 4      0.00  162.08

# %%
# Drop the index from SQL export
data.drop(columns=["Unnamed: 0"], axis=1, inplace=True)

# %%
# Parse timestamp
data["DimPostingDateId"] = pd.to_datetime(data["DimPostingDateId"], format="%Y%m%d")

# %% [markdown]
# ## Create product info table

# %%
# Select only product relalted features
product_info = data[['ItemNo2','Color','Gender','Category','SUB Category', 'SUB Category2', 'Quality', 'Origin Country']].drop_duplicates()
product_info.reset_index(drop=True, inplace=True)
product_info
# Out:
#                  ItemNo2           Color      Gender  Category SUB Category  \
# 0    F15404308_CLR000021           Black  WOMENSWEAR  Trousers     Trousers
# 1    M00012003_CLR000508      White mel     MENSWEAR      Tops    Crew neck
# 2    F19123672_CLR000021           Black  WOMENSWEAR    Shirts       Shirts
# 3    F19123672_CLR000289     Clear Cream  WOMENSWEAR    Shirts       Shirts
# 4    M00012307_CLR000650  Blue Iris Mel     MENSWEAR      Tops       V-neck
# ..                   ...             ...         ...       ...          ...
# 695  M24400088_190414TCX    FOREST NIGHT    MENSWEAR    Shirts       Shirts
# 696  F24200090_CLR000021           Black  WOMENSWEAR    Skirts         Maxi
# 697  M24300006_CLR000589  Black Blizzard    MENSWEAR     Jeans        Jeans
# 698  F24400186_CLR000021           Black  WOMENSWEAR  Knitwear     Cardigan
# 699  M24300005_CLR001978       Dark moon    MENSWEAR     Jeans        Jeans
#
#     SUB Category2 Quality Origin Country
# 0         Default   Woven          China
# 1    Short sleeve  Jersey         Turkey
# 2    Short sleeve   Woven          China
# 3    Short sleeve   Woven          China
# 4    Short sleeve  Jersey         Turkey
# ..            ...     ...            ...
# 695       Default   Woven          China
# 696       Default   Woven          China
# 697       Default   Denim         Turkey
# 698   Long sleeve    Knit          China
# 699       Default   Denim         Turkey
#
# [700 rows x 8 columns]

# %% [markdown]
# ## Sample by week

# %%
# Sample weekly data
data_id_time_target = data.set_index("DimPostingDateId").groupby('ItemNo2').resample('W')['Quantity'].sum().reset_index()
data_id_time_target
# Out:
#                    ItemNo2 DimPostingDateId  Quantity
# 0      F00001015_CLR000021       2022-03-20      66.0
# 1      F00001015_CLR000021       2022-03-27      92.0
# 2      F00001015_CLR000021       2022-04-03      90.0
# 3      F00001015_CLR000021       2022-04-10      70.0
# 4      F00001015_CLR000021       2022-04-17      78.0
# ...                    ...              ...       ...
# 56821     S00029_CLR001336       2024-08-11       0.0
# 56822     S00029_CLR001336       2024-08-18       4.0
# 56823     S00029_CLR001336       2024-08-25       2.0
# 56824     S00029_CLR001336       2024-09-01       1.0
# 56825  U10000002_CLR002314       2024-09-29     370.0
#
# [56826 rows x 3 columns]

# %% [markdown]
# ## Calc MAE

# %%
def calc_mae_by_product_id(product_id, df):
    # Select records by product_id
    product_data = df.loc[df["ItemNo2"] == product_id]
    
    # Check if contains enough records
    if product_data.shape[0] < 16:
        return
    
    forecast = product_data.iloc[-16:-8]
    forecast.reset_index(drop=True, inplace=True)
    target = product_data.iloc[-8:]
    target.reset_index(drop=True, inplace=True)

    # Calc MAE
    result = (abs(target["Quantity"] - forecast["Quantity"])).mean()
    return result

# %%
# Apply mae calculation and store in a new column
product_info["naive_mae"] = product_info["ItemNo2"].apply(calc_mae_by_product_id, args=(data_id_time_target,))

# %%
product_info.head(20)
# Out:
